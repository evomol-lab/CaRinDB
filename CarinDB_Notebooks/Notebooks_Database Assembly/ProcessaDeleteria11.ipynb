# %% [markdown]
# #0 - Basic Settings

# %%
#Permission to access any file on Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Increasing the viewing capacity of columns and rows.
import pandas as pd

pd.set_option('display.max_columns', 7000)
pd.set_option('display.max_rows',90000)

# %% [markdown]
# #1 - Generation of the target attribute (*Deleteria11*) in the database with 33 cancers

# %% [markdown]
# The target attribute will be calculated:
# - Deleteria11

# %%
#Reading Base_33Tecidos_Missense.csv database
import pandas as pd
base_33 = pd.read_csv("drive/My Drive/ProcessaNovaBase/Integracao33BasesTratamentosFinais/Base_33Tecidos_Missense.csv", low_memory = False, delimiter='\t')

# %%
base_33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25124 entries, 0 to 25123
# Data columns (total 93 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CHROM                         25124 non-null  int64
#  1   POS                           25124 non-null  int64
#  2   REF                           25124 non-null  object
#  3   ALT                           25124 non-null  object
#  4   Interpro_domain               25124 non-null  object
#  5   dbNSFP_DEOGEN2_pred           25124 non-null  object
#  6   dbNSFP_MetaSVM_pred           25124 non-null  object
#  7   dbNSFP_fathmmMKL_coding_pred  25124 non-null  object
#  8   dbNSFP_PrimateAI_pred         25124 non-null  object
#  9   dbNSFP_PROVEAN_pred           25124 non-null  object
#  10  dbNSFP_MCAP_pred              25124 non-null  object
#  11  dbNSFP_ClinPred_pred          25124 non-null  object
#  12  dbNSFP_BayesDel_addAF_pred    25124 non-null  object
#  13  dbNSFP_ExAC_AF                25124 non-null  float64
#  14  dbNSFP_Polyphen2_HVAR_pred    25124 non-null  object
#  15  dbNSFP_SIFT_pred              25124 non-null  object
#  16  dbNSFP_FATHMM_pred            25124 non-null  object
#  17  dbNSFP_SIFT4G_pred            25124 non-null  object
#  18  dbNSFP_LRT_pred               25124 non-null  object
#  19  dbNSFP_fathmmXF_coding_pred   25124 non-null  object
#  20  dbNSFP_BayesDel_noAF_pred     25124 non-null  object
#  21  dbNSFP_gnomAD_exomes_AF       25124 non-null  float64
#  22  dbNSFP_Aloft_pred             25124 non-null  object
#  23  dbNSFP_MutationTaster_pred    25124 non-null  object
#  24  dbNSFP_MetaLR_pred            25124 non-null  object
#  25  dbNSFP_LISTS2_pred            25124 non-null  object
#  26  dbNSFP_Polyphen2_HDIV_pred    25124 non-null  object
#  27  dbNSFP_MutationAssessor_pred  25124 non-null  object
#  28  VariantEffect_EFF             25124 non-null  object
#  29  Risco_Mut_EFF                 25124 non-null  object
#  30  Tipo_Mut_EFF                  25124 non-null  object
#  31  Point_Mutation_EFF            25124 non-null  object
#  32  changeProt_EFF                25124 non-null  object
#  33  changecDNA_EFF                25124 non-null  object
#  34  Gene_EFF                      25124 non-null  object
#  35  RefSeq_EFF                    25124 non-null  object
#  36  Exon_EFF                      25124 non-null  int64
#  37  Pos_Point_Mutation_EFF        25124 non-null  int64
#  38  poschangecDNA_EFF             25124 non-null  int64
#  39  typechangecDNA_EFF            25124 non-null  object
#  40  aminBefore                    25124 non-null  object
#  41  aminAfter                     25124 non-null  object
#  42  poschangeProt                 25124 non-null  int64
#  43  typechangeProt                25124 non-null  object
#  44  SNP_ID_COMMON                 25124 non-null  object
#  45  COMMON                        25124 non-null  float64
#  46  PolyPhen2_Dam_pred            25124 non-null  int64
#  47  Ndamage                       25124 non-null  object
#  48  NdamageCalc                   25124 non-null  int64
#  49  Deleteria                     25124 non-null  int64
#  50  Deleteria5                    25124 non-null  int64
#  51  Deleteria10                   25124 non-null  int64
#  52  Uniprot_id                    25124 non-null  object
#  53  PDB_id                        25124 non-null  object
#  54  Resolution                    25124 non-null  float64
#  55  Swiss-Prot                    25124 non-null  object
#  56  db_align_beg                  25124 non-null  float64
#  57  db_align_end                  25124 non-null  float64
#  58  pdbx_auth_seq_align_beg       25124 non-null  float64
#  59  pdbx_auth_seq_align_end       25124 non-null  float64
#  60  pdbx_strand_id                25124 non-null  object
#  61  seq_align_beg                 25124 non-null  float64
#  62  seq_align_end                 25124 non-null  float64
#  63  db_name                       25124 non-null  object
#  64  pdbx_align_begin              25124 non-null  object
#  65  pdbx_seq_one_letter_code      25124 non-null  object
#  66  len_seq                       25124 non-null  float64
#  67  Blosum62                      25124 non-null  object
#  68  groupBefore                   25124 non-null  object
#  69  groupAfter                    25124 non-null  object
#  70  groupChange                   25124 non-null  object
#  71  aminBeforeEssential           25124 non-null  int64
#  72  aminAfterEssential            25124 non-null  object
#  73  essencialChange               25124 non-null  object
#  74  substitution                  25124 non-null  int64
#  75  NodeId_RING                   25124 non-null  object
#  76  Dssp_RING                     25124 non-null  object
#  77  Degree_RING                   25124 non-null  float64
#  78  Bfactor_CA_RING               25124 non-null  float64
#  79  Inter_Lig_tot                 25124 non-null  float64
#  80  Inter_Res_tot                 25124 non-null  float64
#  81  Inter_IAC_Lig_tot             25124 non-null  float64
#  82  Inter_VDW_Lig_tot             25124 non-null  float64
#  83  Inter_VDW_Res_tot             25124 non-null  float64
#  84  Inter_HBOND_Res_tot           25124 non-null  float64
#  85  Inter_PIPISTACK_Res_tot       25124 non-null  float64
#  86  Inter_IONIC_Res_tot           25124 non-null  float64
#  87  Inter_SSBOND_Res_tot          25124 non-null  float64
#  88  Inter_PICATION_Res_tot        25124 non-null  float64
#  89  triangles_node                25124 non-null  float64
#  90  clusteringCoef_node           25124 non-null  float64
#  91  betweennessWeighted_node      25124 non-null  float64
#  92  Tecido                        25124 non-null  object
# dtypes: float64(26), int64(13), object(54)
# memory usage: 17.8+ MB

# %%
#Identify duplicates records in the data
dupes=base_33.duplicated()
sum(dupes)
# Out:
# 0

# %% [markdown]
# ##1.1 Deleteria11

# %% [markdown]
# The Target attribute will be the **Deleteria11** attribute.
#
# The **Deleteria11** attribute will be calculated as follows:
#
# - Expression1: The **SIFT** attribute, or the **PolyPhen2_Dan** attribute   or the  **PROVEAN** attribute should have the value **D** or **P**.
#
# - Expression2: The **dbNSFP_gnomAD_exomes_AF** attribute should be less than 10 raised to -4.
#
# - Expression3:The **NdamageCalc** attribute should be >= 11
#
# - Expression4: The **COMMON** attribute should be 0
#
# The **Deleteria11** attribute  = Expression1 **and** Expression2 **and** Expression3 **and** Expression4

# %%
#The or and and python statements require truth-values.
#For pandas these are considered ambiguous so you should use "bitwise" | (or) or & (and) operations:
#Extract from  https://stackoverflow.com/questions/36921951/truth-value-of-a-series-is-ambiguous-use-a-empty-a-bool-a-item-a-any-o

SIFT = base_33["dbNSFP_SIFT_pred"].apply(lambda x:True if (x == "D" or x == "P") else False)
PolyPhen2 = base_33["PolyPhen2_Dam_pred"].apply(lambda x:True if (x == 1) else False)
PROVEAN = base_33['dbNSFP_PROVEAN_pred'].apply(lambda x:True if (x == "D" or x == "P") else False)
exp1 = SIFT | PolyPhen2 |PROVEAN

# %%
exp2 = base_33['dbNSFP_gnomAD_exomes_AF'].apply(lambda x:True if (x < 0.0001) else False)

# %%
exp3 = base_33['NdamageCalc'].apply(lambda x:True if (x >= 11) else False)

# %%
exp4 = base_33['COMMON'].apply(lambda x:True if (x == 0) else False)

# %%
base_33['Deleteria11'] = exp1 & exp2 & exp3 & exp4
base_33['Deleteria11'] = base_33['Deleteria11'].apply(lambda x:1 if(x == True) else 0)

# %%
base_33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25124 entries, 0 to 25123
# Data columns (total 94 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CHROM                         25124 non-null  int64
#  1   POS                           25124 non-null  int64
#  2   REF                           25124 non-null  object
#  3   ALT                           25124 non-null  object
#  4   Interpro_domain               25124 non-null  object
#  5   dbNSFP_DEOGEN2_pred           25124 non-null  object
#  6   dbNSFP_MetaSVM_pred           25124 non-null  object
#  7   dbNSFP_fathmmMKL_coding_pred  25124 non-null  object
#  8   dbNSFP_PrimateAI_pred         25124 non-null  object
#  9   dbNSFP_PROVEAN_pred           25124 non-null  object
#  10  dbNSFP_MCAP_pred              25124 non-null  object
#  11  dbNSFP_ClinPred_pred          25124 non-null  object
#  12  dbNSFP_BayesDel_addAF_pred    25124 non-null  object
#  13  dbNSFP_ExAC_AF                25124 non-null  float64
#  14  dbNSFP_Polyphen2_HVAR_pred    25124 non-null  object
#  15  dbNSFP_SIFT_pred              25124 non-null  object
#  16  dbNSFP_FATHMM_pred            25124 non-null  object
#  17  dbNSFP_SIFT4G_pred            25124 non-null  object
#  18  dbNSFP_LRT_pred               25124 non-null  object
#  19  dbNSFP_fathmmXF_coding_pred   25124 non-null  object
#  20  dbNSFP_BayesDel_noAF_pred     25124 non-null  object
#  21  dbNSFP_gnomAD_exomes_AF       25124 non-null  float64
#  22  dbNSFP_Aloft_pred             25124 non-null  object
#  23  dbNSFP_MutationTaster_pred    25124 non-null  object
#  24  dbNSFP_MetaLR_pred            25124 non-null  object
#  25  dbNSFP_LISTS2_pred            25124 non-null  object
#  26  dbNSFP_Polyphen2_HDIV_pred    25124 non-null  object
#  27  dbNSFP_MutationAssessor_pred  25124 non-null  object
#  28  VariantEffect_EFF             25124 non-null  object
#  29  Risco_Mut_EFF                 25124 non-null  object
#  30  Tipo_Mut_EFF                  25124 non-null  object
#  31  Point_Mutation_EFF            25124 non-null  object
#  32  changeProt_EFF                25124 non-null  object
#  33  changecDNA_EFF                25124 non-null  object
#  34  Gene_EFF                      25124 non-null  object
#  35  RefSeq_EFF                    25124 non-null  object
#  36  Exon_EFF                      25124 non-null  int64
#  37  Pos_Point_Mutation_EFF        25124 non-null  int64
#  38  poschangecDNA_EFF             25124 non-null  int64
#  39  typechangecDNA_EFF            25124 non-null  object
#  40  aminBefore                    25124 non-null  object
#  41  aminAfter                     25124 non-null  object
#  42  poschangeProt                 25124 non-null  int64
#  43  typechangeProt                25124 non-null  object
#  44  SNP_ID_COMMON                 25124 non-null  object
#  45  COMMON                        25124 non-null  float64
#  46  PolyPhen2_Dam_pred            25124 non-null  int64
#  47  Ndamage                       25124 non-null  object
#  48  NdamageCalc                   25124 non-null  int64
#  49  Deleteria                     25124 non-null  int64
#  50  Deleteria5                    25124 non-null  int64
#  51  Deleteria10                   25124 non-null  int64
#  52  Uniprot_id                    25124 non-null  object
#  53  PDB_id                        25124 non-null  object
#  54  Resolution                    25124 non-null  float64
#  55  Swiss-Prot                    25124 non-null  object
#  56  db_align_beg                  25124 non-null  float64
#  57  db_align_end                  25124 non-null  float64
#  58  pdbx_auth_seq_align_beg       25124 non-null  float64
#  59  pdbx_auth_seq_align_end       25124 non-null  float64
#  60  pdbx_strand_id                25124 non-null  object
#  61  seq_align_beg                 25124 non-null  float64
#  62  seq_align_end                 25124 non-null  float64
#  63  db_name                       25124 non-null  object
#  64  pdbx_align_begin              25124 non-null  object
#  65  pdbx_seq_one_letter_code      25124 non-null  object
#  66  len_seq                       25124 non-null  float64
#  67  Blosum62                      25124 non-null  object
#  68  groupBefore                   25124 non-null  object
#  69  groupAfter                    25124 non-null  object
#  70  groupChange                   25124 non-null  object
#  71  aminBeforeEssential           25124 non-null  int64
#  72  aminAfterEssential            25124 non-null  object
#  73  essencialChange               25124 non-null  object
#  74  substitution                  25124 non-null  int64
#  75  NodeId_RING                   25124 non-null  object
#  76  Dssp_RING                     25124 non-null  object
#  77  Degree_RING                   25124 non-null  float64
#  78  Bfactor_CA_RING               25124 non-null  float64
#  79  Inter_Lig_tot                 25124 non-null  float64
#  80  Inter_Res_tot                 25124 non-null  float64
#  81  Inter_IAC_Lig_tot             25124 non-null  float64
#  82  Inter_VDW_Lig_tot             25124 non-null  float64
#  83  Inter_VDW_Res_tot             25124 non-null  float64
#  84  Inter_HBOND_Res_tot           25124 non-null  float64
#  85  Inter_PIPISTACK_Res_tot       25124 non-null  float64
#  86  Inter_IONIC_Res_tot           25124 non-null  float64
#  87  Inter_SSBOND_Res_tot          25124 non-null  float64
#  88  Inter_PICATION_Res_tot        25124 non-null  float64
#  89  triangles_node                25124 non-null  float64
#  90  clusteringCoef_node           25124 non-null  float64
#  91  betweennessWeighted_node      25124 non-null  float64
#  92  Tecido                        25124 non-null  object
#  93  Deleteria11                   25124 non-null  int64
# dtypes: float64(26), int64(14), object(54)
# memory usage: 18.0+ MB

# %%
base_33[['dbNSFP_SIFT_pred','PolyPhen2_Dam_pred', 'dbNSFP_PROVEAN_pred', 'dbNSFP_gnomAD_exomes_AF', 'NdamageCalc', 'COMMON', 'Deleteria', 'Deleteria5', 'Deleteria10', 'Deleteria11']]
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Identify duplicates records in the data
dupes=base_33.duplicated()
sum(dupes)
# Out:
# 0

# %%
base_33['Deleteria10'].value_counts()
# Out:
# 1    14177
# 0    10947
# Name: Deleteria10, dtype: int64

# %%
base_33['Deleteria11'].value_counts()
# Out:
# 1    12898
# 0    12226
# Name: Deleteria11, dtype: int64

# %% [markdown]
# ##1.2 Generating a file with the 33 cancer database with the *Deleteria11* attribute.

# %%
base_33.to_csv("drive/My Drive/ProcessaNovaBase/Integracao33BasesTratamentosFinais/Base_33Tecidos_MissensecomDeleteria11.csv",sep='\t',index=False)

# %% [markdown]
# #2 - Generation of the target attribute (Deleteria11) in the database for the article with 33 cancers

# %% [markdown]
# The target attribute will be calculated:
# - Deleteria11

# %%
#Reading Base_33Tecidos_clean.csv database
import pandas as pd
base_33 = pd.read_csv("drive/My Drive/ProcessaNovaBase/TratamentosFinais_Base_33_Artigo_Base/Base_33Tecidos_clean.csv", low_memory = False, delimiter='\t')

# %%
base_33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26893 entries, 0 to 26892
# Data columns (total 93 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CHROM                         26893 non-null  int64
#  1   POS                           26893 non-null  int64
#  2   REF                           26893 non-null  object
#  3   ALT                           26893 non-null  object
#  4   Interpro_domain               26893 non-null  object
#  5   dbNSFP_DEOGEN2_pred           26893 non-null  object
#  6   dbNSFP_MetaSVM_pred           26893 non-null  object
#  7   dbNSFP_fathmmMKL_coding_pred  26893 non-null  object
#  8   dbNSFP_PrimateAI_pred         26893 non-null  object
#  9   dbNSFP_PROVEAN_pred           26893 non-null  object
#  10  dbNSFP_MCAP_pred              26893 non-null  object
#  11  dbNSFP_ClinPred_pred          26893 non-null  object
#  12  dbNSFP_BayesDel_addAF_pred    26893 non-null  object
#  13  dbNSFP_ExAC_AF                26893 non-null  float64
#  14  dbNSFP_Polyphen2_HVAR_pred    26893 non-null  object
#  15  dbNSFP_SIFT_pred              26893 non-null  object
#  16  dbNSFP_FATHMM_pred            26893 non-null  object
#  17  dbNSFP_SIFT4G_pred            26893 non-null  object
#  18  dbNSFP_LRT_pred               26893 non-null  object
#  19  dbNSFP_fathmmXF_coding_pred   26893 non-null  object
#  20  dbNSFP_BayesDel_noAF_pred     26893 non-null  object
#  21  dbNSFP_gnomAD_exomes_AF       26893 non-null  float64
#  22  dbNSFP_Aloft_pred             26893 non-null  object
#  23  dbNSFP_MutationTaster_pred    26893 non-null  object
#  24  dbNSFP_MetaLR_pred            26893 non-null  object
#  25  dbNSFP_LISTS2_pred            26893 non-null  object
#  26  dbNSFP_Polyphen2_HDIV_pred    26893 non-null  object
#  27  dbNSFP_MutationAssessor_pred  26893 non-null  object
#  28  VariantEffect_EFF             26893 non-null  object
#  29  Risco_Mut_EFF                 26893 non-null  object
#  30  Tipo_Mut_EFF                  26893 non-null  object
#  31  Point_Mutation_EFF            26893 non-null  object
#  32  changeProt_EFF                26893 non-null  object
#  33  changecDNA_EFF                26893 non-null  object
#  34  Gene_EFF                      26893 non-null  object
#  35  RefSeq_EFF                    26893 non-null  object
#  36  Exon_EFF                      26893 non-null  int64
#  37  Pos_Point_Mutation_EFF        26893 non-null  int64
#  38  poschangecDNA_EFF             26893 non-null  int64
#  39  typechangecDNA_EFF            26893 non-null  object
#  40  aminBefore                    26893 non-null  object
#  41  aminAfter                     26893 non-null  object
#  42  poschangeProt                 26893 non-null  int64
#  43  typechangeProt                26893 non-null  object
#  44  SNP_ID_COMMON                 26893 non-null  object
#  45  COMMON                        26893 non-null  float64
#  46  PolyPhen2_Dam_pred            26893 non-null  int64
#  47  Ndamage                       26893 non-null  object
#  48  NdamageCalc                   26893 non-null  int64
#  49  Deleteria                     26893 non-null  int64
#  50  Deleteria5                    26893 non-null  int64
#  51  Deleteria10                   26893 non-null  int64
#  52  Uniprot_id                    26893 non-null  object
#  53  PDB_id                        26893 non-null  object
#  54  Resolution                    26893 non-null  float64
#  55  Swiss-Prot                    26893 non-null  object
#  56  db_align_beg                  26893 non-null  float64
#  57  db_align_end                  26893 non-null  float64
#  58  pdbx_auth_seq_align_beg       26893 non-null  float64
#  59  pdbx_auth_seq_align_end       26893 non-null  float64
#  60  pdbx_strand_id                26893 non-null  object
#  61  seq_align_beg                 26893 non-null  float64
#  62  seq_align_end                 26893 non-null  float64
#  63  db_name                       26893 non-null  object
#  64  pdbx_align_begin              26893 non-null  object
#  65  pdbx_seq_one_letter_code      26893 non-null  object
#  66  len_seq                       26893 non-null  float64
#  67  Blosum62                      26893 non-null  object
#  68  groupBefore                   26893 non-null  object
#  69  groupAfter                    26893 non-null  object
#  70  groupChange                   26893 non-null  object
#  71  aminBeforeEssential           26893 non-null  int64
#  72  aminAfterEssential            26893 non-null  object
#  73  essencialChange               26893 non-null  object
#  74  substitution                  26893 non-null  int64
#  75  NodeId_RING                   26893 non-null  object
#  76  Dssp_RING                     26893 non-null  object
#  77  Degree_RING                   26893 non-null  float64
#  78  Bfactor_CA_RING               26893 non-null  float64
#  79  Inter_Lig_tot                 26893 non-null  float64
#  80  Inter_Res_tot                 26893 non-null  float64
#  81  Inter_IAC_Lig_tot             26893 non-null  float64
#  82  Inter_VDW_Lig_tot             26893 non-null  float64
#  83  Inter_VDW_Res_tot             26893 non-null  float64
#  84  Inter_HBOND_Res_tot           26893 non-null  float64
#  85  Inter_PIPISTACK_Res_tot       26893 non-null  float64
#  86  Inter_IONIC_Res_tot           26893 non-null  float64
#  87  Inter_SSBOND_Res_tot          26893 non-null  float64
#  88  Inter_PICATION_Res_tot        26893 non-null  float64
#  89  triangles_node                26893 non-null  float64
#  90  clusteringCoef_node           26893 non-null  float64
#  91  betweennessWeighted_node      26893 non-null  float64
#  92  Tecido                        26893 non-null  object
# dtypes: float64(26), int64(13), object(54)
# memory usage: 19.1+ MB

# %%
#Identify duplicates records in the data
dupes=base_33.duplicated()
sum(dupes)
# Out:
# 0

# %% [markdown]
# ##2.1 Deleteria11

# %% [markdown]
# The Target attribute will be the **Deleteria11** attribute.
#
# The **Deleteria11** attribute will be calculated as follows:
#
# - Expression1: The **SIFT** attribute, or the **PolyPhen2_Dan** attribute   or the  **PROVEAN** attribute should have the value **D** or **P**.
#
# - Expression2: The **dbNSFP_gnomAD_exomes_AF** attribute should be less than 10 raised to -4.
#
# - Expression3:The **NdamageCalc** attribute should be >= 11
#
# - Expression4: The **COMMON** attribute should be 0
#
# The **Deleteria11** attribute  = Expression1 **and** Expression2 **and** Expression3 **and** Expression4

# %%
#The or and and python statements require truth-values.
#For pandas these are considered ambiguous so you should use "bitwise" | (or) or & (and) operations:
#Extract from  https://stackoverflow.com/questions/36921951/truth-value-of-a-series-is-ambiguous-use-a-empty-a-bool-a-item-a-any-o

SIFT = base_33["dbNSFP_SIFT_pred"].apply(lambda x:True if (x == "D" or x == "P") else False)
PolyPhen2 = base_33["PolyPhen2_Dam_pred"].apply(lambda x:True if (x == 1) else False)
PROVEAN = base_33['dbNSFP_PROVEAN_pred'].apply(lambda x:True if (x == "D" or x == "P") else False)
exp1 = SIFT | PolyPhen2 |PROVEAN

# %%
exp2 = base_33['dbNSFP_gnomAD_exomes_AF'].apply(lambda x:True if (x < 0.0001) else False)

# %%
exp3 = base_33['NdamageCalc'].apply(lambda x:True if (x >= 11) else False)

# %%
exp4 = base_33['COMMON'].apply(lambda x:True if (x == 0) else False)

# %%
base_33['Deleteria11'] = exp1 & exp2 & exp3 & exp4
base_33['Deleteria11'] = base_33['Deleteria11'].apply(lambda x:1 if(x == True) else 0)

# %%
base_33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26893 entries, 0 to 26892
# Data columns (total 94 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CHROM                         26893 non-null  int64
#  1   POS                           26893 non-null  int64
#  2   REF                           26893 non-null  object
#  3   ALT                           26893 non-null  object
#  4   Interpro_domain               26893 non-null  object
#  5   dbNSFP_DEOGEN2_pred           26893 non-null  object
#  6   dbNSFP_MetaSVM_pred           26893 non-null  object
#  7   dbNSFP_fathmmMKL_coding_pred  26893 non-null  object
#  8   dbNSFP_PrimateAI_pred         26893 non-null  object
#  9   dbNSFP_PROVEAN_pred           26893 non-null  object
#  10  dbNSFP_MCAP_pred              26893 non-null  object
#  11  dbNSFP_ClinPred_pred          26893 non-null  object
#  12  dbNSFP_BayesDel_addAF_pred    26893 non-null  object
#  13  dbNSFP_ExAC_AF                26893 non-null  float64
#  14  dbNSFP_Polyphen2_HVAR_pred    26893 non-null  object
#  15  dbNSFP_SIFT_pred              26893 non-null  object
#  16  dbNSFP_FATHMM_pred            26893 non-null  object
#  17  dbNSFP_SIFT4G_pred            26893 non-null  object
#  18  dbNSFP_LRT_pred               26893 non-null  object
#  19  dbNSFP_fathmmXF_coding_pred   26893 non-null  object
#  20  dbNSFP_BayesDel_noAF_pred     26893 non-null  object
#  21  dbNSFP_gnomAD_exomes_AF       26893 non-null  float64
#  22  dbNSFP_Aloft_pred             26893 non-null  object
#  23  dbNSFP_MutationTaster_pred    26893 non-null  object
#  24  dbNSFP_MetaLR_pred            26893 non-null  object
#  25  dbNSFP_LISTS2_pred            26893 non-null  object
#  26  dbNSFP_Polyphen2_HDIV_pred    26893 non-null  object
#  27  dbNSFP_MutationAssessor_pred  26893 non-null  object
#  28  VariantEffect_EFF             26893 non-null  object
#  29  Risco_Mut_EFF                 26893 non-null  object
#  30  Tipo_Mut_EFF                  26893 non-null  object
#  31  Point_Mutation_EFF            26893 non-null  object
#  32  changeProt_EFF                26893 non-null  object
#  33  changecDNA_EFF                26893 non-null  object
#  34  Gene_EFF                      26893 non-null  object
#  35  RefSeq_EFF                    26893 non-null  object
#  36  Exon_EFF                      26893 non-null  int64
#  37  Pos_Point_Mutation_EFF        26893 non-null  int64
#  38  poschangecDNA_EFF             26893 non-null  int64
#  39  typechangecDNA_EFF            26893 non-null  object
#  40  aminBefore                    26893 non-null  object
#  41  aminAfter                     26893 non-null  object
#  42  poschangeProt                 26893 non-null  int64
#  43  typechangeProt                26893 non-null  object
#  44  SNP_ID_COMMON                 26893 non-null  object
#  45  COMMON                        26893 non-null  float64
#  46  PolyPhen2_Dam_pred            26893 non-null  int64
#  47  Ndamage                       26893 non-null  object
#  48  NdamageCalc                   26893 non-null  int64
#  49  Deleteria                     26893 non-null  int64
#  50  Deleteria5                    26893 non-null  int64
#  51  Deleteria10                   26893 non-null  int64
#  52  Uniprot_id                    26893 non-null  object
#  53  PDB_id                        26893 non-null  object
#  54  Resolution                    26893 non-null  float64
#  55  Swiss-Prot                    26893 non-null  object
#  56  db_align_beg                  26893 non-null  float64
#  57  db_align_end                  26893 non-null  float64
#  58  pdbx_auth_seq_align_beg       26893 non-null  float64
#  59  pdbx_auth_seq_align_end       26893 non-null  float64
#  60  pdbx_strand_id                26893 non-null  object
#  61  seq_align_beg                 26893 non-null  float64
#  62  seq_align_end                 26893 non-null  float64
#  63  db_name                       26893 non-null  object
#  64  pdbx_align_begin              26893 non-null  object
#  65  pdbx_seq_one_letter_code      26893 non-null  object
#  66  len_seq                       26893 non-null  float64
#  67  Blosum62                      26893 non-null  object
#  68  groupBefore                   26893 non-null  object
#  69  groupAfter                    26893 non-null  object
#  70  groupChange                   26893 non-null  object
#  71  aminBeforeEssential           26893 non-null  int64
#  72  aminAfterEssential            26893 non-null  object
#  73  essencialChange               26893 non-null  object
#  74  substitution                  26893 non-null  int64
#  75  NodeId_RING                   26893 non-null  object
#  76  Dssp_RING                     26893 non-null  object
#  77  Degree_RING                   26893 non-null  float64
#  78  Bfactor_CA_RING               26893 non-null  float64
#  79  Inter_Lig_tot                 26893 non-null  float64
#  80  Inter_Res_tot                 26893 non-null  float64
#  81  Inter_IAC_Lig_tot             26893 non-null  float64
#  82  Inter_VDW_Lig_tot             26893 non-null  float64
#  83  Inter_VDW_Res_tot             26893 non-null  float64
#  84  Inter_HBOND_Res_tot           26893 non-null  float64
#  85  Inter_PIPISTACK_Res_tot       26893 non-null  float64
#  86  Inter_IONIC_Res_tot           26893 non-null  float64
#  87  Inter_SSBOND_Res_tot          26893 non-null  float64
#  88  Inter_PICATION_Res_tot        26893 non-null  float64
#  89  triangles_node                26893 non-null  float64
#  90  clusteringCoef_node           26893 non-null  float64
#  91  betweennessWeighted_node      26893 non-null  float64
#  92  Tecido                        26893 non-null  object
#  93  Deleteria11                   26893 non-null  int64
# dtypes: float64(26), int64(14), object(54)
# memory usage: 19.3+ MB

# %%
base_33[['dbNSFP_SIFT_pred','PolyPhen2_Dam_pred', 'dbNSFP_PROVEAN_pred', 'dbNSFP_gnomAD_exomes_AF', 'NdamageCalc', 'COMMON', 'Deleteria', 'Deleteria5', 'Deleteria10', 'Deleteria11']]
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Identify duplicates records in the data
dupes=base_33.duplicated()
sum(dupes)
# Out:
# 0

# %%
base_33['Deleteria10'].value_counts()
# Out:
# 1    15894
# 0    10999
# Name: Deleteria10, dtype: int64

# %%
base_33['Deleteria11'].value_counts()
# Out:
# 1    14615
# 0    12278
# Name: Deleteria11, dtype: int64

# %% [markdown]
# ##2.1 Generating a file with the article database 33 cancer with the *Deleteria11* attribute

# %%
base_33.to_csv("drive/My Drive/ProcessaNovaBase/TratamentosFinais_Base_33_Artigo_Base/Base_33Tecidos_cleancomDeleteria11.csv",sep='\t',index=False)
